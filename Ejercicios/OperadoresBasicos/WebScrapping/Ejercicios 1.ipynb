# %% [markdown]
# # Estudio de web scraping : SportFishing

# %% [markdown]
# ### Importación Librería
#
# requests --> Librería para la consulta de los Hipertextos de la Web
#
# Beautifulsoup4 --> Librería para el manejo de listas y el parseo correcto de las listas.

# %%
import requests 
import bs4 

url = 'https://www.pescaenperu.com/categoria-producto/equipos-pesca/'
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.97 Safari/537.36'}
response = requests.get(url, headers = headers)
print(response.status_code)
#print(response.url)
#print(response.apparent_encoding)
#print(response.request)
print(response.text)
# Out:
# 200
# <!DOCTYPE html>
# <!--[if IE 9 ]><html class="no-js ie9" lang="es"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!--><html class="no-js" lang="es"> <!--<![endif]-->
#     <head>
#         <meta charset="UTF-8">
#                     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#                 <link rel="profile" href="http://gmpg.org/xfn/11">
#         <link rel="pingback" href="https://www.pescaenperu.com/xmlrpc.php">
#         <link rel="shortcut icon" href="https:"/>
#
#         <link rel="apple-touch-icon-precomposed" href="https:"/>
#        <!--[if lte IE 9]><script src="http://cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7/html5shiv.js"></script><![endif]-->
#         				<script>document.documentElement.className = document.documentElement.className + ' yes-js js_active js'</script>
# 			<title>Equipos de Pesca archivos | SportFishing Perú | Tienda de artículos de pesca deportiva en Perú</title>
# ...

# %%
print(response.headers)
# Out:
# {'Date': 'Tue, 26 May 2020 04:53:28 GMT', 'Server': 'Apache', 'X-Frame-Options': 'SAMEORIGIN', 'Link': '<https://www.pescaenperu.com/wp-json/>; rel="https://api.w.org/"', 'Content-Encoding': 'gzip', 'Vary': 'Accept-Encoding', 'Upgrade': 'h2,h2c', 'Connection': 'Upgrade, Keep-Alive', 'Cache-Control': 'max-age=0', 'Expires': 'Tue, 26 May 2020 04:53:28 GMT', 'Keep-Alive': 'timeout=3, max=100', 'Transfer-Encoding': 'chunked', 'Content-Type': 'text/html; charset=UTF-8'}

# %%
for i , e in response.headers.items() :
    print("{}  :  {}".format(i,e))
# Out:
# Date  :  Tue, 26 May 2020 04:53:28 GMT
# Server  :  Apache
# X-Frame-Options  :  SAMEORIGIN
# Link  :  <https://www.pescaenperu.com/wp-json/>; rel="https://api.w.org/"
# Content-Encoding  :  gzip
# Vary  :  Accept-Encoding
# Upgrade  :  h2,h2c
# Connection  :  Upgrade, Keep-Alive
# Cache-Control  :  max-age=0
# Expires  :  Tue, 26 May 2020 04:53:28 GMT
# Keep-Alive  :  timeout=3, max=100
# Transfer-Encoding  :  chunked
# Content-Type  :  text/html; charset=UTF-8
