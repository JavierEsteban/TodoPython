# %% [markdown]
# # Analisis Mundiales
#
# Es un archivo de analisis de mundiales descargados de la fuente de kagle.

# %%
# cargando librerías necesarias..
import pandas as pd
import numpy as np
from datetime import datetime


ruta_archivo = "D://Cursos//Python//Ejercicios//DataSet//MundialChampions.csv"

data = pd.read_csv(ruta_archivo, sep = ',')
data
# Out:
#              date     home_team   away_team  home_score  away_score  \
# 0      1872-11-30      Scotland     England           0           0
# 1      1873-03-08       England    Scotland           4           2
# 2      1874-03-07      Scotland     England           2           1
# 3      1875-03-06       England    Scotland           2           2
# 4      1876-03-04      Scotland     England           3           0
# ...           ...           ...         ...         ...         ...
# 41238  2019-10-20       Lesotho    Zimbabwe           0           0
# 41239  2019-10-20        Guinea     Senegal           1           0
# 41240  2019-10-20          Mali  Mauritania           2           0
# 41241  2019-10-20  Burkina Faso       Ghana           0           0
# 41242  2019-10-20   Ivory Coast       Niger           1           0
#
#                                     tournament          city       country  \
# ...

# %% [markdown]
# #### Analisis del Dataframe

# %% [markdown]
# Ordenando la data en base a las fechas para el analisis exploratorio...

# %%
DataOrdenada = data.sort_values(by= "date", ascending = "False")
DataOrdenada
# Out:
#              date     home_team                 away_team  home_score  \
# 0      1872-11-30      Scotland                   England           0
# 1      1873-03-08       England                  Scotland           4
# 2      1874-03-07      Scotland                   England           2
# 3      1875-03-06       England                  Scotland           2
# 4      1876-03-04      Scotland                   England           3
# ...           ...           ...                       ...         ...
# 41241  2019-10-20  Burkina Faso                     Ghana           0
# 41236  2019-10-20      DR Congo  Central African Republic           4
# 41235  2019-10-20         Congo         Equatorial Guinea           1
# 41237  2019-10-20         Libya                   Tunisia           1
# 41242  2019-10-20   Ivory Coast                     Niger           1
#
#        away_score                               tournament          city  \
# ...

# %%
# fechas de los mundiales

serie = pd.Series(DataOrdenada['date'])
serie.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-45ce34910c49> in <module>
#       1 # fechas de los mundiales
#       2
# ----> 3 serie = pd.Series(DataOrdenada['date'].year)
#       4 serie.unique()
#
# d:\cursos\python\ejercicios\operadoresbasicos\javier\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'year'

# %%
DataOrdenada.describe()
# Out:
#          home_score    away_score
# count  41243.000000  41243.000000
# mean       1.744975      1.189317
# std        1.750513      1.406648
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      1.000000
# 75%        2.000000      2.000000
# max       31.000000     21.000000
